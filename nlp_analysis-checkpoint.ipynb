# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
# Load dataset
df = pd.read_csv("../data/reviews.csv")

# Show first rows
df.head()
# Out:
#                              Review  Rating
# 0  Doctor was very kind and helpful       5
# 1          Waiting time is too long       2
# 2           Staff behavior was rude       1
# 3   Clean hospital and fast service       4
# 4             Poor hygiene in rooms       1

# %%
# Dataset info
df.info()

# Missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  171 non-null    object
#  1   Rating  171 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.8+ KB
# Review    0
# Rating    0
# dtype: int64

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KIIT0001\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\KIIT0001\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    text = text.lower()  # lowercase
    text = re.sub(r'[^a-zA-Z]', ' ', text)  # remove symbols
    words = text.split()  # tokenize
    words = [lemmatizer.lemmatize(w) for w in words if w not in stop_words]
    return " ".join(words)

# %%
df['cleaned_review'] = df['Review'].apply(clean_text)

df.head()
# Out:
#                              Review  Rating               cleaned_review
# 0  Doctor was very kind and helpful       5          doctor kind helpful
# 1          Waiting time is too long       2            waiting time long
# 2           Staff behavior was rude       1          staff behavior rude
# 3   Clean hospital and fast service       4  clean hospital fast service
# 4             Poor hygiene in rooms       1            poor hygiene room

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\kiit0001\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\kiit0001\anaconda3\lib\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: click in c:\users\kiit0001\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\kiit0001\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kiit0001\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\kiit0001\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\kiit0001\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)

# %%
# !python -m textblob.download_corpora
# Out:
# Finished.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\KIIT0001\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\KIIT0001\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\KIIT0001\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\KIIT0001\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\KIIT0001\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\KIIT0001\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!

# %%
from textblob import TextBlob

# Sentiment score
df['sentiment_score'] = df['Review'].apply(lambda x: TextBlob(x).sentiment.polarity)

# Convert to label
def get_sentiment(score):
    if score > 0:
        return "Positive"
    elif score < 0:
        return "Negative"
    else:
        return "Neutral"

df['sentiment'] = df['sentiment_score'].apply(get_sentiment)

df.head()
# Out:
#                              Review  Rating               cleaned_review  \
# 0  Doctor was very kind and helpful       5          doctor kind helpful
# 1          Waiting time is too long       2            waiting time long
# 2           Staff behavior was rude       1          staff behavior rude
# 3   Clean hospital and fast service       4  clean hospital fast service
# 4             Poor hygiene in rooms       1            poor hygiene room
#
#    sentiment_score sentiment
# 0         0.780000  Positive
# 1        -0.050000  Negative
# 2        -0.300000  Negative
# 3         0.283333  Positive
# 4        -0.400000  Negative

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Positive    85
# Negative    46
# Neutral     40
# Name: count, dtype: int64

# %%
df['sentiment'].value_counts().plot(kind='bar')
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()

# %%
# !pip install wordcloud matplotlib
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: matplotlib in c:\users\kiit0001\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\kiit0001\anaconda3\lib\site-packages (from wordcloud) (2.3.5)
# Requirement already satisfied: pillow in c:\users\kiit0001\anaconda3\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kiit0001\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kiit0001\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kiit0001\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kiit0001\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kiit0001\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kiit0001\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud

text = " ".join(df['cleaned_review'])

wc = WordCloud(width=800, height=400).generate(text)

plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
df.to_csv("final_healthcare_data.csv", index=False)
